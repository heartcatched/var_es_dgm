# %%
# for correct relative imports
import sys; sys.path.append("../var_es_dgm")

# %%
import warnings
warnings.filterwarnings("ignore")

import torch
from torch.utils.data import DataLoader, TensorDataset

from diffusers import DDPMScheduler
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import scipy.stats

from sklearn.preprocessing import StandardScaler

from var_es_dgm import TimeGrad
from var_es_dgm.basic_models.deepvar import DeepVaR
from var_es_dgm.basic_models.deepar import DeepAR
from var_es_dgm.basic_models import HistoricalSimulation, VarCov
from var_es_dgm.stat_tests import generate_report
from var_es_dgm.utils import seed_everything, compute_individual_returns, compute_portfolio_returns, estimate_var_es_torch

from arch import arch_model

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set_context("paper")

# %%
DATA_FOLDER = "../../data/"
df = pd.read_csv(DATA_FOLDER + "complete_stocks.csv")
df["Date"] = pd.to_datetime(df["Date"])

# %%
len(df["Ticker"].unique())
# Out:
# 89

# %% [markdown]
# ## 1%

# %%
res_timeGrad = list()
res_deepar_normal = list()
res_deepar_student = list()
res_deepvar_paper = list()
res_garch = list() 
res_hist = list()
res_varcov = list()
alpha=0.01
RANDOM_STATE = 12

for i in range(5):
    # one complete cycle
    seed_everything(RANDOM_STATE + i)
    n_stocks = 10
    tickers = np.random.choice(df["Ticker"].unique(), n_stocks, replace=False)
    weights = 1/n_stocks
    print("Portfolio = {0}".format(" + ".join([f"{weights} * {i}"for i in tickers])))
    df_copy = df.loc[df["Ticker"].isin(tickers)].copy(deep=True)

    df_returns = compute_individual_returns(df_copy)
    df_returns = compute_portfolio_returns(df_returns)

    univariate_target = df_returns["Return_Target"]

    univariate_target = univariate_target.values[1:]
    train_size = df_returns[df_returns.Date <= "2022-06-01"].index[-1] + 1
    test_size = len(univariate_target) - train_size
    train = univariate_target[:train_size]

    ss = StandardScaler()
    train_scaled = torch.tensor(ss.fit_transform(train.reshape(-1, 1)), dtype=torch.float32)

    seed_everything(RANDOM_STATE)
    context_size = 90
    num_train_samples = 3000
    train_data = torch.zeros(num_train_samples, context_size, train_scaled.shape[1])
    train_target = torch.zeros(num_train_samples, 1, train_scaled.shape[1])
    train_idx = np.random.choice(np.arange(context_size, train_scaled.shape[0]), num_train_samples, replace=False)
    
    for i in tqdm(range(num_train_samples)):
        idx = train_idx[i]
        train_context = train_scaled[idx-context_size:idx]
        target_obs = train_scaled[idx]
        train_data[i] = train_context
        train_target[i] = target_obs

    train_loader = DataLoader(TensorDataset(train_data, train_target), batch_size=128, shuffle=False)


    temp = torch.tensor(ss.transform(univariate_target.reshape(-1, 1)))
    test_data_context = torch.zeros(test_size, context_size, temp.shape[1])
    test_data_real = torch.zeros(test_size, 1, temp.shape[1])
    for i in range(test_size):
        idx = i + train_size
        test_data_context[i] = temp[idx-context_size:idx]
        test_data_real[i] = temp[idx]

    seed_everything(RANDOM_STATE)
    sheduler = DDPMScheduler(num_train_timesteps=18, beta_end=0.2901444414255984, clip_sample=False)
    model = TimeGrad(1, 1, hidden_size=50, num_layers=2, scheduler=sheduler, num_inference_steps=18)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001898390960977473)
    device = "cuda"
    n_epochs = 88
    model.to(device);

    model.fit(train_loader, optimizer, n_epochs, device)

    seed_everything(RANDOM_STATE)
    VaR_TimeGrad = torch.zeros(test_data_real.shape[0])
    ES_TimeGrad = torch.zeros(test_data_real.shape[0])
    
    for i in tqdm(range(test_data_real.shape[0])):
        test = test_data_context[[i]]
        VaR_TimeGrad[i], ES_TimeGrad[i] = estimate_var_es_torch(model, test, alpha=alpha, n_samples=500, device=device)

    res_timeGrad.append(generate_report(test_data_real.flatten(), VaR_TimeGrad, ES_TimeGrad, alpha=alpha))

    # 2.DeepAR (student)
    n_epochs = 20
    seed_everything(RANDOM_STATE)
    model_deepvar_student = DeepAR(
        target_dim=1,  
        input_size=train_data.shape[2],  
        hidden_size=64,  
        num_layers=2,  
        dropout_rate=0.4,
        dist_type='student' 
    )

    optimizer_deepvar = torch.optim.Adam(model_deepvar_student.parameters(), lr=1e-3)
    model_deepvar_student.to(device)

    model_deepvar_student.fit(train_loader, optimizer_deepvar, n_epochs=n_epochs, device=device)

    VaR_deepvar = torch.zeros(test_data_real.shape[0])
    ES_deepvar = torch.zeros(test_data_real.shape[0])
    
    for i in tqdm(range(test_data_real.shape[0]), desc="Testing DeepAR(Student)"):
        test = test_data_context[[i]].to(device)
        VaR_deepvar[i], ES_deepvar[i] = estimate_var_es_torch(model_deepvar_student, test, alpha=alpha, n_samples=500, device=device)

    res_deepar_student.append(generate_report(test_data_real.flatten(), VaR_deepvar, ES_deepvar, alpha=alpha))

    # 3.DeepAR (Normal)
    seed_everything(RANDOM_STATE)
    model_deepvar = DeepAR(
        target_dim=1,  
        input_size=train_data.shape[2],  
        hidden_size=64,  
        num_layers=2,  
        dropout_rate=0.4,
        dist_type='normal' 
    )

    optimizer_deepvar = torch.optim.Adam(model_deepvar.parameters(), lr=1e-3)
    model_deepvar.to(device)

    model_deepvar.fit(train_loader, optimizer_deepvar, n_epochs=n_epochs, device=device)

    VaR_deepvar = torch.zeros(test_data_real.shape[0])
    ES_deepvar = torch.zeros(test_data_real.shape[0])
    
    for i in tqdm(range(test_data_real.shape[0]), desc="Testing DeepAR(Normal)"):
        test = test_data_context[[i]].to(device)
        VaR_deepvar[i], ES_deepvar[i] = estimate_var_es_torch(model_deepvar, test, alpha=alpha, n_samples=500, device=device)

    res_deepar_normal.append(generate_report(test_data_real.flatten(), VaR_deepvar, ES_deepvar, alpha=alpha))

    # 4.DeepVaR (Paper)
    deepvar_framework = DeepVaR(
        model=model_deepvar_student,
        scaler=ss,           
        alpha=alpha,
        n_samples=500,       
        device=device
    )

    VaR_deepvar_paper = torch.zeros(test_data_real.shape[0])
    ES_deepvar_paper = torch.zeros(test_data_real.shape[0])
    
    for i in tqdm(range(test_data_real.shape[0]), desc="Testing DeepVaR (Paper Framework)"):
        test = test_data_context[[i]].to(device)
        v, e = deepvar_framework.predict(test)
        VaR_deepvar_paper[i] = v
        ES_deepvar_paper[i] = e

    res_deepvar_paper.append(generate_report(test_data_real.flatten(), VaR_deepvar_paper, ES_deepvar_paper, alpha=alpha))

    # 5. GARCH(1,1) Model 
    VaR_garch = torch.zeros(test_size)
    ES_garch = torch.zeros(test_size)
    
    for j in tqdm(range(test_size), desc="Testing GARCH(1,1)"):
        idx = j + train_size
        start_idx = max(0, idx - 900)
        
        hist_returns = univariate_target[start_idx:idx]
        
        am = arch_model(hist_returns * 100, vol='Garch', p=1, q=1, dist='Normal')
        res = am.fit(disp='off', show_warning=False)
        forecasts = res.forecast(horizon=1, reindex=False)
        
        mu = forecasts.mean.iloc[-1, 0] / 100
        sigma = np.sqrt(forecasts.variance.iloc[-1, 0]) / 100
        
        q = scipy.stats.norm.ppf(alpha)
        VaR_garch[j] = (mu + sigma * q)
        pdf_q = scipy.stats.norm.pdf(q)
        ES_garch[j] = (mu - sigma * (pdf_q / alpha))

    VaR_garch_scaled = torch.tensor(
        ss.transform(VaR_garch.numpy().reshape(-1, 1)).flatten(), 
        dtype=torch.float32
    )
    ES_garch_scaled = torch.tensor(
        ss.transform(ES_garch.numpy().reshape(-1, 1)).flatten(), 
        dtype=torch.float32
    )

    res_garch.append(generate_report(test_data_real.flatten(), VaR_garch_scaled, ES_garch_scaled, alpha=alpha))

    # Результаты для других моделей
    hist_sim = HistoricalSimulation(alpha=alpha)
    VaR_histSim = torch.zeros(test_data_real.shape[0])
    ES_histSim = torch.zeros(test_data_real.shape[0])
    
    for i in tqdm(range(test_data_real.shape[0])):
        test = test_data_context[[i]]
        VaR_histSim[i], ES_histSim[i] = hist_sim.predict(test)
    
    res_hist.append(generate_report(test_data_real.flatten(), VaR_histSim, ES_histSim, alpha=alpha))
    
    var_cov = VarCov(alpha=alpha)
    
    VaR_varCov = torch.zeros(test_data_real.shape[0])
    ES_varCov = torch.zeros(test_data_real.shape[0])
    
    for i in tqdm(range(test_data_real.shape[0])):
        test = test_data_context[[i]]
        VaR_varCov[i], ES_varCov[i] = var_cov.predict(test)
    
    res_varcov.append(generate_report(test_data_real.flatten(), VaR_varCov, ES_varCov, alpha=alpha))

    # Выводим результаты для всех моделей
    print("\n--- Results for Iteration ---")
    print("TimeGrad:      ", res_timeGrad[-1])
    print("DeepAR Normal: ", res_deepar_normal[-1])
    print("DeepAR Student:", res_deepar_student[-1])
    print("DeepVaR Paper: ", res_deepvar_paper[-1])
    print("GARCH(1,1):    ", res_garch[-1])
    print("HistSim:       ", res_hist[-1])
    print("VarCov:        ", res_varcov[-1])
# Out:
# Portfolio = 0.1 * INTC + 0.1 * DHR + 0.1 * COP + 0.1 * MRK + 0.1 * HON + 0.1 * T + 0.1 * MSFT + 0.1 * AXP + 0.1 * PEP + 0.1 * SYK
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Student):   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Normal):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing DeepVaR (Paper Framework):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing GARCH(1,1):   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# --- Results for Iteration ---
# TimeGrad:       {'Kupicks POF': 0.6137847837437679, 'Haas TBF': 0.09629362094787298, 'Christoffersen Test': 0.6889123271805955, 'Kupicks Test': 0.6137847837437679, 'Acerbi Szekely 1': 2.080815553665161, 'Acerbi Szekely 2': 0.00026272921240888536}
# DeepAR Normal:  {'Kupicks POF': 0.02908250748684615, 'Haas TBF': 0.10593944505322493, 'Christoffersen Test': 0.6095576274760497, 'Kupicks Test': 0.02908250748684615, 'Acerbi Szekely 1': 2.1340558528900146, 'Acerbi Szekely 2': 0.00048501271521672606}
# DeepAR Student: {'Kupicks POF': 0.33831157927013206, 'Haas TBF': 0.5248012305912865, 'Christoffersen Test': 0.6657300145970582, 'Kupicks Test': 0.33831157927013206, 'Acerbi Szekely 1': 2.0087544918060303, 'Acerbi Szekely 2': 0.0003043567412532866}
# DeepVaR Paper:  {'Kupicks POF': 0.33831157927013206, 'Haas TBF': 0.16659908486382047, 'Christoffersen Test': 0.6657300145970582, 'Kupicks Test': 0.33831157927013206, 'Acerbi Szekely 1': 1.9926633834838867, 'Acerbi Szekely 2': 0.00030191868427209556}
# GARCH(1,1):     {'Kupicks POF': 0.07305825532264572, 'Haas TBF': 0.1666791540979932, 'Christoffersen Test': 0.6265206970953923, 'Kupicks Test': 0.07305825532264572, 'Acerbi Szekely 1': 2.0625038146972656, 'Acerbi Szekely 2': 0.000416667404351756}
# HistSim:        {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.49884875144285634, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 2.0848894119262695, 'Acerbi Szekely 2': 0.00015794615319464356}
# VarCov:         {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.49884875144285634, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 2.188063383102417, 'Acerbi Szekely 2': 0.00016576237976551056}
# Portfolio = 0.1 * GE + 0.1 * ELV + 0.1 * DE + 0.1 * PG + 0.1 * BLK + 0.1 * CI + 0.1 * NVDA + 0.1 * MCD + 0.1 * NFLX + 0.1 * AAPL
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Student):   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Normal):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing DeepVaR (Paper Framework):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing GARCH(1,1):   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# --- Results for Iteration ---
# TimeGrad:       {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.2390510679695951, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 2.0859217643737793, 'Acerbi Szekely 2': 0.00015802436973899603}
# DeepAR Normal:  {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.3351296385266322, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 2.2743499279022217, 'Acerbi Szekely 2': 0.00022973230807110667}
# DeepAR Student: {'Kupicks POF': 0.6137847837437679, 'Haas TBF': 0.14201892604567917, 'Christoffersen Test': 0.6889123271805955, 'Kupicks Test': 0.6137847837437679, 'Acerbi Szekely 1': 1.8814750909805298, 'Acerbi Szekely 2': 0.00023755997244734317}
# DeepVaR Paper:  {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.711060186291624, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 1.8603401184082031, 'Acerbi Szekely 2': 0.00014093484787736088}
# GARCH(1,1):     {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.2390510679695951, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 2.316106081008911, 'Acerbi Szekely 2': 0.00017546257004141808}
# HistSim:        {'Kupicks POF': 0.33831157927013206, 'Haas TBF': 0.1916379571863886, 'Christoffersen Test': 0.6657300145970582, 'Kupicks Test': 0.33831157927013206, 'Acerbi Szekely 1': 1.9543298482894897, 'Acerbi Szekely 2': 0.0002961105783469975}
# VarCov:         {'Kupicks POF': 0.07409886583668099, 'Haas TBF': nan, 'Christoffersen Test': 0.8409252037375214, 'Kupicks Test': 0.07409886583668099, 'Acerbi Szekely 1': 2.124439239501953, 'Acerbi Szekely 2': 5.3647454478777945e-05}
# Portfolio = 0.1 * BA + 0.1 * KO + 0.1 * ACN + 0.1 * AMD + 0.1 * GE + 0.1 * COP + 0.1 * TMO + 0.1 * MO + 0.1 * NEE + 0.1 * CVX
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Student):   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Normal):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing DeepVaR (Paper Framework):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing GARCH(1,1):   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# --- Results for Iteration ---
# TimeGrad:       {'Kupicks POF': 0.27384288964871895, 'Haas TBF': 0.6403059923438319, 'Christoffersen Test': 0.7862839203990928, 'Kupicks Test': 0.27384288964871895, 'Acerbi Szekely 1': 1.8751771450042725, 'Acerbi Szekely 2': 9.470590885030106e-05}
# DeepAR Normal:  {'Kupicks POF': 0.16597135395565904, 'Haas TBF': 0.334643788429077, 'Christoffersen Test': 0.6451174048888443, 'Kupicks Test': 0.16597135395565904, 'Acerbi Szekely 1': 1.9728929996490479, 'Acerbi Szekely 2': 0.0003487437206786126}
# DeepAR Student: {'Kupicks POF': 0.33831157927013206, 'Haas TBF': 0.015310056586571922, 'Christoffersen Test': 0.6657300145970582, 'Kupicks Test': 0.33831157927013206, 'Acerbi Szekely 1': 1.7425438165664673, 'Acerbi Szekely 2': 0.0002640217717271298}
# DeepVaR Paper:  {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.11789620386173068, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 1.8860969543457031, 'Acerbi Szekely 2': 0.0001905148383229971}
# GARCH(1,1):     {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.39313263168562695, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 2.1307976245880127, 'Acerbi Szekely 2': 0.00021523206669371575}
# HistSim:        {'Kupicks POF': 0.27384288964871895, 'Haas TBF': 0.8025191992558134, 'Christoffersen Test': 0.7862839203990928, 'Kupicks Test': 0.27384288964871895, 'Acerbi Szekely 1': 2.2042269706726074, 'Acerbi Szekely 2': 0.00011132458894280717}
# VarCov:         {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.9260455867592424, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 2.0393364429473877, 'Acerbi Szekely 2': 0.00020599357958417386}
# Portfolio = 0.1 * T + 0.1 * TJX + 0.1 * MS + 0.1 * EOG + 0.1 * BAC + 0.1 * BLK + 0.1 * GS + 0.1 * GOOGL + 0.1 * JNJ + 0.1 * HD
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Student):   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Normal):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing DeepVaR (Paper Framework):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing GARCH(1,1):   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# --- Results for Iteration ---
# TimeGrad:       {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.2916841333090041, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 1.9325408935546875, 'Acerbi Szekely 2': 0.00014640460722148418}
# DeepAR Normal:  {'Kupicks POF': 0.16597135395565904, 'Haas TBF': 0.27420149170963126, 'Christoffersen Test': 0.6451174048888443, 'Kupicks Test': 0.16597135395565904, 'Acerbi Szekely 1': 2.048837184906006, 'Acerbi Szekely 2': 0.00036216818261891603}
# DeepAR Student: {'Kupicks POF': 0.6137847837437679, 'Haas TBF': 0.06285858193199298, 'Christoffersen Test': 0.6889123271805955, 'Kupicks Test': 0.6137847837437679, 'Acerbi Szekely 1': 2.0154356956481934, 'Acerbi Szekely 2': 0.00025447417283430696}
# DeepVaR Paper:  {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.8358819946215217, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 1.9154270887374878, 'Acerbi Szekely 2': 0.00019347747729625553}
# GARCH(1,1):     {'Kupicks POF': 0.6137847837437679, 'Haas TBF': 0.5481668967679869, 'Christoffersen Test': 0.6889123271805955, 'Kupicks Test': 0.6137847837437679, 'Acerbi Szekely 1': 2.2216572761535645, 'Acerbi Szekely 2': 0.00028051226399838924}
# HistSim:        {'Kupicks POF': 0.16597135395565904, 'Haas TBF': 0.1813576013518102, 'Christoffersen Test': 0.6451174048888443, 'Kupicks Test': 0.16597135395565904, 'Acerbi Szekely 1': 2.0799975395202637, 'Acerbi Szekely 2': 0.000367676344467327}
# VarCov:         {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.236173913833934, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 2.114431858062744, 'Acerbi Szekely 2': 0.00021357896912377328}
# Portfolio = 0.1 * CB + 0.1 * RTX + 0.1 * MS + 0.1 * NFLX + 0.1 * PG + 0.1 * XOM + 0.1 * MSFT + 0.1 * MDT + 0.1 * C + 0.1 * VZ
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Student):   0%|          | 0/396 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Testing DeepAR(Normal):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing DeepVaR (Paper Framework):   0%|          | 0/396 [00:00<?, ?it/s]
# Testing GARCH(1,1):   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
#   0%|          | 0/396 [00:00<?, ?it/s]
# --- Results for Iteration ---
# TimeGrad:       {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.6550137424716964, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 1.852778673171997, 'Acerbi Szekely 2': 0.00018714935868047178}
# DeepAR Normal:  {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.6550137424716964, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 2.011335849761963, 'Acerbi Szekely 2': 0.00020316524023655802}
# DeepAR Student: {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.8505315642980683, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 1.7230972051620483, 'Acerbi Szekely 2': 0.00013053766451776028}
# DeepVaR Paper:  {'Kupicks POF': 0.27384288964871895, 'Haas TBF': 0.3852746317969885, 'Christoffersen Test': 0.7862839203990928, 'Kupicks Test': 0.27384288964871895, 'Acerbi Szekely 1': 1.8306314945220947, 'Acerbi Szekely 2': 9.245613182429224e-05}
# GARCH(1,1):     {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.054210710548835375, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 2.0510053634643555, 'Acerbi Szekely 2': 0.00020717225561384112}
# HistSim:        {'Kupicks POF': 0.9839089602677263, 'Haas TBF': 0.11777640619725117, 'Christoffersen Test': 0.7155219203146557, 'Kupicks Test': 0.9839089602677263, 'Acerbi Szekely 1': 1.9719154834747314, 'Acerbi Szekely 2': 0.00019918337056878954}
# VarCov:         {'Kupicks POF': 0.6124944699749673, 'Haas TBF': 0.35891287510350023, 'Christoffersen Test': 0.747017734035957, 'Kupicks Test': 0.6124944699749673, 'Acerbi Szekely 1': 1.91619074344635, 'Acerbi Szekely 2': 0.00014516596274916083}

# %%
print(np.array([list(i.values()) for i in res_timeGrad]).mean(axis=0))
print(np.array([list(i.values()) for i in res_deepar_student]).mean(axis=0))
print(np.array([list(i.values()) for i in res_deepar_normal]).mean(axis=0))
print(np.array([list(i.values()) for i in res_deepvar_paper]).mean(axis=0))
print(np.array([list(i.values()) for i in res_garch]).mean(axis=0))
print(np.array([list(i.values()) for i in res_hist]).mean(axis=0))
print(np.array([list(i.values()) for i in res_varcov]).mean(axis=0))
# Out:
# [6.19305115e-01 3.84469711e-01 7.36950727e-01 6.19305115e-01
#  1.96544681e+00 1.69802691e-04]
# [5.03337439e-01 3.19104072e-01 6.91260484e-01 5.03337439e-01
#  1.87426126e+00 2.38190065e-04]
# [4.65768627e-01 3.40985621e-01 6.66167256e-01 4.65768627e-01
#  2.08829436e+00 3.25764433e-04]
# [6.38493372e-01 4.43342420e-01 7.26015102e-01 6.38493372e-01
#  1.89703181e+00 1.83860396e-04]
# [6.53431086e-01 2.80248092e-01 6.98698920e-01 6.53431086e-01
#  2.15641403e+00 2.59009312e-04]
# [4.74905851e-01 3.58427983e-01 7.11934199e-01 4.74905851e-01
#  2.05907185e+00 2.26448207e-04]
# [6.53381145e-01            nan 7.53200902e-01 6.53381145e-01
#  2.07649233e+00 1.56829669e-04]
